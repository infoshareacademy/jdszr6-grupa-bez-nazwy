# %%
import glob2
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = glob2.glob("train/*")
species = []
for f in files:
    species.append(f[6:]) # birds species list

# %% [markdown]
# Birds information data scrap from wikipedia - to be updated

# %%
# # %%script false --no-raise-error # dont execute cell

# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.common.exceptions import NoSuchElementException
# import re

# webpage = r"https://en.wikipedia.org/wiki/Main_Page"

# for searchterm in species[:4]:

#     driver = webdriver.Chrome()
#     driver.minimize_window()
#     driver.get(webpage)

#     # find search-box
#     sbox = driver.find_element(By.CLASS_NAME, "vector-search-box-input")
#     try:
#         sbox.send_keys(searchterm) # write searching keywords in search-box
#         submit = driver.find_element(By.ID, "searchButton")
#         submit.click()

#         try: # if searchterm correction is available - use it
#             driver.find_element(By.XPATH, "//*[@class='mw-search-result'][1]/div[1]/a").click()
#             found = "found with 'did you mean' correction"
#         except NoSuchElementException:
#             found = "found"
        
#         # get basic information of specie
#         basic_info = driver.find_element(By.XPATH, '//*[@id="mw-content-text"]/div[1]/p[2]').text
#         # clean text
#         basic_info = re.sub('\s?\[.*?\]', '', basic_info).strip()
    
#     except NoSuchElementException:
#         found = "NOT found"

#     print("searching for", searchterm, "-", found)

#     try: # look for 'description' heading
#         driver.find_element(By.ID, "Description")
#         description = driver.find_element(By.XPATH, '//*[@id="Description"]/parent::h2/following-sibling::p').text
#         description = re.sub('\s?\[.*?\]', '', description).strip()
#     except NoSuchElementException:
#         description = ""

#     driver.close()

#     print("information sample:", basic_info[:75])
#     print("description sample:", description[:75])

# %% [markdown]
# Definition to create array of bird species catalogues

# %%
def get_species_dataset(directory, species_count = None, img_count = None):
                                # reduced number of species and images per specie
    target = []

    zero = glob2.glob(os.path.join(directory, species[0])+"/*")[0]
    zero_img = cv2.cvtColor(cv2.imread(zero),cv2.COLOR_BGR2RGB).reshape(1,224,224,3)

    for specie in species[:species_count]:
        specie_id = species.index(specie)
        specie_imgs = glob2.glob(os.path.join(directory, specie)+"/*")

        if not img_count:
            img_count = len(specie_imgs)
            
        for img in specie_imgs[:img_count]:
            tmp_img = cv2.cvtColor(cv2.imread(img),cv2.COLOR_BGR2RGB).reshape(1,224,224,3)
            
            if specie == species[0] and img == specie_imgs[0]:
                dataset = zero_img
                
            else:
                dataset = np.concatenate((dataset, tmp_img ), axis=0)

            target.append(specie_id)
            
    target_arr = np.array(target).reshape(-1,1)

    print("            dataset shape:", dataset.shape)
    print("             target shape:", target_arr.shape)
    print("target classes and counts:", dict((i, target.count(i)) for i in target))

    return dataset, target_arr

# %% [markdown]
# Dataset for DL training

# %%
num_class = 10

# %%
x_train, y_train = get_species_dataset("train", num_class)
# Out:
#             dataset shape: (1507, 224, 224, 3)
#              target shape: (1507, 1)
# target classes and counts: {0: 166, 1: 166, 2: 166, 3: 137, 4: 146, 5: 137, 6: 130, 7: 133, 8: 161, 9: 165}

# %%
x_test, y_test = get_species_dataset("test", num_class)
x_val, y_val = get_species_dataset("valid", num_class)
# Out:
#             dataset shape: (50, 224, 224, 3)
#              target shape: (50, 1)
# target classes and counts: {0: 5, 1: 5, 2: 5, 3: 5, 4: 5, 5: 5, 6: 5, 7: 5, 8: 5, 9: 5}
#             dataset shape: (50, 224, 224, 3)
#              target shape: (50, 1)
# target classes and counts: {0: 5, 1: 5, 2: 5, 3: 5, 4: 5, 5: 5, 6: 5, 7: 5, 8: 5, 9: 5}

# %%
x_test
# Out:
# array([[[[ 76,  14,  10],
#          [ 56,   0,   0],
#          [ 56,   8,   0],
#          ...,
#          [120, 144, 116],
#          [152, 176, 148],
#          [174, 202, 176]],
#
#         [[ 70,   8,   4],
#          [ 62,   2,   0],
#          [ 58,   8,   0],
#          ...,
#          [ 92, 116,  92],
#          [120, 148, 122],
#          [154, 182, 156]],
#
#         [[ 84,  22,  16],
#          [ 78,  20,  12],
#          [ 68,  18,  10],
#          ...,
#          [ 76, 102,  82],
#          [110, 136, 116],
#          [146, 172, 152]],
#
#         ...,
#
#         [[  0,   4,   0],
#          [  0,   2,   0],
#          [  0,   2,   0],
#          ...,
#          [ 76, 126,  10],
#          [ 70, 126,   8],
#          [ 70, 126,   8]],
#
#         [[  0,   2,   0],
#          [  0,   2,   0],
#          [  0,   2,   0],
#          ...,
#          [ 72, 122,   6],
#          [ 68, 118,   2],
#          [ 66, 116,   0]],
#
#         [[  0,   2,   0],
#          [  0,   2,   0],
#          [  0,   2,   0],
#          ...,
#          [ 66, 114,   0],
#          [ 68, 118,   2],
#          [ 72, 122,   6]]],
#
#
#        [[[246, 225, 160],
#          [245, 224, 159],
#          [246, 221, 157],
#          ...,
#          [205, 148,  96],
#          [192, 135,  83],
#          [187, 130,  78]],
#
#         [[247, 226, 161],
#          [246, 225, 162],
#          [252, 227, 163],
#          ...,
#          [172, 116,  65],
#          [200, 144,  93],
#          [166, 109,  58]],
#
#         [[242, 221, 158],
#          [243, 222, 159],
#          [224, 200, 136],
#          ...,
#          [177, 123,  76],
#          [175, 121,  74],
#          [155, 101,  54]],
#
#         ...,
#
#         [[ 61, 119,  97],
#          [ 58, 116,  93],
#          [ 56, 117,  93],
#          ...,
#          [ 52,  53,  21],
#          [ 53,  51,  20],
#          [ 51,  49,  18]],
#
#         [[ 66, 121, 101],
#          [ 58, 114,  94],
#          [ 59, 118,  97],
#          ...,
#          [ 52,  54,  19],
#          [ 53,  52,  18],
#          [ 51,  50,  16]],
#
#         [[ 69, 123, 106],
#          [ 63, 118,  98],
#          [ 45, 104,  81],
#          ...,
#          [ 52,  54,  19],
#          [ 53,  52,  18],
#          [ 51,  50,  16]]],
#
#
#        [[[231, 234, 151],
#          [232, 235, 152],
#          [233, 236, 155],
#          ...,
#          [183, 198, 105],
#          [181, 196, 103],
#          [183, 198, 105]],
#
#         [[232, 235, 152],
#          [231, 234, 153],
#          [232, 235, 154],
#          ...,
#          [188, 203, 110],
#          [182, 197, 104],
#          [179, 194, 101]],
#
#         [[232, 235, 154],
#          [233, 236, 155],
#          [233, 236, 155],
#          ...,
#          [186, 201, 108],
#          [183, 198, 105],
#          [182, 197, 104]],
#
#         ...,
#
#         [[247,  45, 114],
#          [241,  39, 107],
#          [238,  39, 106],
#          ...,
#          [166, 172,  92],
#          [163, 169,  89],
#          [163, 169,  89]],
#
#         [[246,  44, 112],
#          [243,  41, 109],
#          [240,  41, 108],
#          ...,
#          [165, 172,  89],
#          [167, 174,  91],
#          [163, 170,  87]],
#
#         [[249,  47, 115],
#          [241,  39, 107],
#          [238,  39, 104],
#          ...,
#          [166, 173,  90],
#          [164, 171,  88],
#          [165, 172,  89]]],
#
#
#        ...,
#
#
#        [[[145, 146, 140],
#          [148, 149, 143],
#          [153, 154, 148],
#          ...,
#          [ 82,  61,  41],
#          [ 79,  60,  37],
#          [ 74,  55,  32]],
#
#         [[152, 153, 147],
#          [155, 156, 150],
#          [159, 160, 154],
#          ...,
#          [ 81,  58,  40],
#          [ 74,  53,  33],
#          [ 70,  50,  27]],
#
#         [[144, 146, 137],
#          [151, 153, 144],
#          [159, 161, 152],
#          ...,
#          [ 72,  46,  31],
#          [ 71,  45,  28],
#          [ 64,  41,  23]],
#
#         ...,
#
#         [[ 81,  64,  26],
#          [ 64,  47,   9],
#          [ 71,  51,  14],
#          ...,
#          [ 12,  22,   0],
#          [ 14,  24,   1],
#          [ 17,  27,   4]],
#
#         [[ 71,  54,  16],
#          [ 66,  49,  11],
#          [ 75,  58,  20],
#          ...,
#          [  5,  15, 249],
#          [  7,  17, 251],
#          [ 12,  22, 255]],
#
#         [[ 60,  43,   5],
#          [ 65,  48,  10],
#          [ 83,  66,  28],
#          ...,
#          [  7,  17, 251],
#          [ 16,  24,   3],
#          [ 19,  27,   3]]],
#
#
#        [[[160, 176, 100],
#          [162, 176, 103],
#          [161, 175, 104],
#          ...,
#          [176, 181, 127],
#          [173, 180, 123],
#          [170, 177, 118]],
#
#         [[157, 173,  97],
#          [159, 173, 100],
#          [160, 174, 103],
#          ...,
#          [176, 181, 127],
#          [174, 181, 124],
#          [172, 179, 120]],
#
#         [[156, 172,  96],
#          [157, 171,  98],
#          [160, 174, 103],
#          ...,
#          [175, 181, 127],
#          [175, 182, 125],
#          [173, 180, 121]],
#
#         ...,
#
#         [[135, 108,  25],
#          [137, 110,  29],
#          [160, 133,  56],
#          ...,
#          [ 70,  95, 242],
#          [ 58,  87, 227],
#          [ 33,  64, 203]],
#
#         [[119,  91,  10],
#          [125,  98,  17],
#          [142, 114,  40],
#          ...,
#          [ 90, 114,   5],
#          [ 86, 113, 254],
#          [ 79, 106, 245]],
#
#         [[129, 101,  20],
#          [152, 124,  45],
#          [174, 146,  72],
#          ...,
#          [ 68,  94, 243],
#          [ 60,  84, 227],
#          [ 55,  78, 218]]],
#
#
#        [[[185, 186, 179],
#          [193, 194, 186],
#          [205, 207, 196],
#          ...,
#          [ 48,  49,  45],
#          [ 45,  45,  45],
#          [ 33,  33,  35]],
#
#         [[196, 197, 190],
#          [197, 198, 190],
#          [198, 200, 189],
#          ...,
#          [ 51,  52,  48],
#          [ 46,  46,  45],
#          [ 22,  22,  22]],
#
#         [[200, 201, 193],
#          [196, 197, 189],
#          [197, 199, 188],
#          ...,
#          [ 36,  39,  32],
#          [ 38,  40,  36],
#          [ 21,  23,  22]],
#
#         ...,
#
#         [[238, 225, 217],
#          [233, 220, 212],
#          [233, 220, 211],
#          ...,
#          [193, 191, 186],
#          [195, 193, 188],
#          [195, 193, 188]],
#
#         [[244, 236, 226],
#          [240, 229, 220],
#          [236, 225, 216],
#          ...,
#          [181, 179, 174],
#          [192, 190, 185],
#          [212, 210, 205]],
#
#         [[242, 233, 226],
#          [229, 221, 211],
#          [224, 213, 204],
#          ...,
#          [224, 222, 217],
#          [249, 247, 242],
#          [247, 245, 240]]]], dtype=uint8)

# %%
y_test
# Out:
# array([[ 0],
#        [ 0],
#        [ 0],
#        [ 0],
#        [ 0],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 4],
#        [ 4],
#        [ 4],
#        [ 4],
#        [ 4],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 8],
#        [ 8],
#        [ 8],
#        [ 8],
#        [ 8],
#        [10],
#        [10],
#        [10],
#        [10],
#        [10],
#        [12],
#        [12],
#        [12],
#        [12],
#        [12],
#        [14],
#        [14],
#        [14],
#        [14],
#        [14],
#        [16],
#        [16],
#        [16],
#        [16],
#        [16],
#        [18],
#        [18],
#        [18],
#        [18],
#        [18]])

# %%
import tensorflow as tf

# %%
from tensorflow.keras import layers

def create_cnn_model(inShape, convNum, hNum, hAct, outNum, loss):
    """
    :param inShape: kształt wejścia, h*w*c
    :param convNum: lista ilości featerów w warstwach konwolucyjnych
    :param hNum: lista ilości neuronów w poszczególnych warstwach ukrytych
    :param hAct: rodzaj aktywacji w warstwach ukrytych, str
    :param outNum: ilość
    :param loss: funkcja kosztu
    """
    # pusty model
    model = tf.keras.Sequential()
    # warstwa wejściowa
    model.add(layers.InputLayer(input_shape=(inShape)))
    # warstwy konwolucyjne
    for idx, oneConvNum in enumerate(convNum):
        # dodajemy kolejną warstwę konwolucyjną
        # zmienia nam ilość cech(kanałów) na oneConvNum
        model.add(layers.Conv2D(
                                filters=oneConvNum,
                                kernel_size=3,
                                strides=1,
                                padding="SAME",
                                activation="relu"
                                )
                            )
        # doajemy następującego po convie maxpool'a
        # zmniejsza nam wymiarowość HxW o połowę
        model.add(layers.MaxPool2D(
                                    pool_size=(2, 2),
                                    strides=2,
                                    padding="SAME"
                                    )
                                )
    # spłaszczamy po konwolucjach, przygotowanie pod relu
    model.add(layers.Flatten())
    # warstwy fully connected
    for idx, oneHidNum in enumerate(hNum):
        # dodajemy warstwę
        model.add(layers.Dense(oneHidNum, activation=hAct))
    # warstwa wyjściowa
    model.add(layers.Dense(outNum))
    # warstwa softmax, dystrybucja prawdopodobieństwa
    model.add(layers.Softmax())
    print(model.summary())
    
    opt = tf.keras.optimizers.Adam()
    
    model.compile(
        optimizer=opt,
        loss=loss,
        metrics=["accuracy"]
    )
    
    return model

# %%
our_cnn = create_cnn_model(
    inShape=(224, 224, 3),
    convNum=[8,16,24,32,40],
    hNum=[50],
    hAct='relu',
    outNum=num_class,
    loss=tf.keras.losses.SparseCategoricalCrossentropy()
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 24)        3480
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 24)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        6944
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 40)        11560
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 40)         0
#  2D)
#
#  flatten (Flatten)           (None, 1960)              0
#
#  dense (Dense)               (None, 50)                98050
#
#  dense_1 (Dense)             (None, 10)                510
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 121,936
# Trainable params: 121,936
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %%
history = our_cnn.fit(
    x=x_train,
    y=y_train,
    epochs=100,
    batch_size=1024,
    validation_data=(x_test,  y_test),
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 17s 5s/step - loss: 10.0659 - accuracy: 0.0896 - val_loss: 10.3446 - val_accuracy: 0.1200
# Epoch 2/100
# 2/2 [==============================] - 16s 5s/step - loss: 8.8995 - accuracy: 0.0962 - val_loss: 5.3523 - val_accuracy: 0.2200
# Epoch 3/100
# 2/2 [==============================] - 16s 5s/step - loss: 5.1064 - accuracy: 0.1327 - val_loss: 4.0245 - val_accuracy: 0.1400
# Epoch 4/100
# 2/2 [==============================] - 16s 5s/step - loss: 3.7982 - accuracy: 0.1314 - val_loss: 3.2846 - val_accuracy: 0.0800
# Epoch 5/100
# 2/2 [==============================] - 16s 5s/step - loss: 3.1094 - accuracy: 0.1121 - val_loss: 2.8310 - val_accuracy: 0.1000
# Epoch 6/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.7111 - accuracy: 0.1241 - val_loss: 2.5493 - val_accuracy: 0.1200
# Epoch 7/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.4735 - accuracy: 0.1321 - val_loss: 2.3952 - val_accuracy: 0.1400
# Epoch 8/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.3582 - accuracy: 0.1473 - val_loss: 2.3313 - val_accuracy: 0.1600
# Epoch 9/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.3076 - accuracy: 0.1374 - val_loss: 2.3148 - val_accuracy: 0.0800
# Epoch 10/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2862 - accuracy: 0.1447 - val_loss: 2.3114 - val_accuracy: 0.0600
# Epoch 11/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2781 - accuracy: 0.1447 - val_loss: 2.3054 - val_accuracy: 0.0600
# Epoch 12/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2729 - accuracy: 0.1393 - val_loss: 2.2958 - val_accuracy: 0.0800
# Epoch 13/100
# 2/2 [==============================] - 17s 5s/step - loss: 2.2671 - accuracy: 0.1533 - val_loss: 2.2846 - val_accuracy: 0.1000
# Epoch 14/100
# 2/2 [==============================] - 17s 5s/step - loss: 2.2595 - accuracy: 0.1533 - val_loss: 2.2685 - val_accuracy: 0.1400
# Epoch 15/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2507 - accuracy: 0.1652 - val_loss: 2.2485 - val_accuracy: 0.2000
# Epoch 16/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2384 - accuracy: 0.1765 - val_loss: 2.2276 - val_accuracy: 0.2200
# Epoch 17/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2233 - accuracy: 0.2064 - val_loss: 2.2062 - val_accuracy: 0.2200
# Epoch 18/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.2042 - accuracy: 0.2177 - val_loss: 2.1846 - val_accuracy: 0.2200
# Epoch 19/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.1819 - accuracy: 0.2230 - val_loss: 2.1572 - val_accuracy: 0.2600
# Epoch 20/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.1560 - accuracy: 0.2223 - val_loss: 2.1180 - val_accuracy: 0.2400
# Epoch 21/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.1222 - accuracy: 0.2329 - val_loss: 2.0647 - val_accuracy: 0.3200
# Epoch 22/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.0824 - accuracy: 0.2548 - val_loss: 2.0043 - val_accuracy: 0.3200
# Epoch 23/100
# 2/2 [==============================] - 16s 5s/step - loss: 2.0334 - accuracy: 0.2794 - val_loss: 1.9346 - val_accuracy: 0.3600
# Epoch 24/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.9783 - accuracy: 0.3039 - val_loss: 1.8650 - val_accuracy: 0.3800
# Epoch 25/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.9169 - accuracy: 0.3311 - val_loss: 1.7958 - val_accuracy: 0.4000
# Epoch 26/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.8553 - accuracy: 0.3663 - val_loss: 1.7160 - val_accuracy: 0.4800
# Epoch 27/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.7903 - accuracy: 0.4035 - val_loss: 1.6357 - val_accuracy: 0.5200
# Epoch 28/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.7263 - accuracy: 0.4313 - val_loss: 1.5618 - val_accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.6595 - accuracy: 0.4466 - val_loss: 1.4810 - val_accuracy: 0.5600
# Epoch 30/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.5938 - accuracy: 0.4638 - val_loss: 1.4188 - val_accuracy: 0.5400
# Epoch 31/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.5305 - accuracy: 0.4844 - val_loss: 1.3840 - val_accuracy: 0.5200
# Epoch 32/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.4735 - accuracy: 0.5189 - val_loss: 1.3038 - val_accuracy: 0.5800
# Epoch 33/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.4196 - accuracy: 0.5315 - val_loss: 1.2305 - val_accuracy: 0.6000
# Epoch 34/100
# 2/2 [==============================] - 16s 5s/step - loss: 1.3699 - accuracy: 0.5521 - val_loss: 1.1555 - val_accuracy: 0.6200
# Epoch 35/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.3143 - accuracy: 0.5879 - val_loss: 1.0939 - val_accuracy: 0.6600
# Epoch 36/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.2713 - accuracy: 0.5952 - val_loss: 1.0466 - val_accuracy: 0.6800
# Epoch 37/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.2206 - accuracy: 0.6171 - val_loss: 0.9764 - val_accuracy: 0.7400
# Epoch 38/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.1752 - accuracy: 0.6330 - val_loss: 0.9583 - val_accuracy: 0.7400
# Epoch 39/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.1393 - accuracy: 0.6324 - val_loss: 0.9205 - val_accuracy: 0.7800
# Epoch 40/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.1016 - accuracy: 0.6476 - val_loss: 0.9065 - val_accuracy: 0.7600
# Epoch 41/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.0650 - accuracy: 0.6616 - val_loss: 0.8658 - val_accuracy: 0.8000
# Epoch 42/100
# 2/2 [==============================] - 15s 5s/step - loss: 1.0308 - accuracy: 0.6695 - val_loss: 0.8233 - val_accuracy: 0.7000
# Epoch 43/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.9937 - accuracy: 0.6934 - val_loss: 0.7943 - val_accuracy: 0.8000
# Epoch 44/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.9561 - accuracy: 0.6921 - val_loss: 0.7831 - val_accuracy: 0.7200
# Epoch 45/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.9108 - accuracy: 0.7160 - val_loss: 0.7260 - val_accuracy: 0.7600
# Epoch 46/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.8995 - accuracy: 0.7147 - val_loss: 0.7293 - val_accuracy: 0.7800
# Epoch 47/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.8625 - accuracy: 0.7266 - val_loss: 0.6805 - val_accuracy: 0.7400
# Epoch 48/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.8362 - accuracy: 0.7392 - val_loss: 0.6771 - val_accuracy: 0.7800
# Epoch 49/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.8019 - accuracy: 0.7465 - val_loss: 0.7000 - val_accuracy: 0.7600
# Epoch 50/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.7714 - accuracy: 0.7591 - val_loss: 0.6445 - val_accuracy: 0.7400
# Epoch 51/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.7485 - accuracy: 0.7684 - val_loss: 0.7080 - val_accuracy: 0.7200
# Epoch 52/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.7274 - accuracy: 0.7678 - val_loss: 0.6609 - val_accuracy: 0.7800
# Epoch 53/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6987 - accuracy: 0.7790 - val_loss: 0.6792 - val_accuracy: 0.6800
# Epoch 54/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6912 - accuracy: 0.7671 - val_loss: 0.6996 - val_accuracy: 0.7800
# Epoch 55/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6921 - accuracy: 0.7731 - val_loss: 0.5885 - val_accuracy: 0.8200
# Epoch 56/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6416 - accuracy: 0.7930 - val_loss: 0.5956 - val_accuracy: 0.7400
# Epoch 57/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6108 - accuracy: 0.8056 - val_loss: 0.6186 - val_accuracy: 0.8000
# Epoch 58/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.6096 - accuracy: 0.8155 - val_loss: 0.5636 - val_accuracy: 0.8000
# Epoch 59/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.5879 - accuracy: 0.8109 - val_loss: 0.6255 - val_accuracy: 0.8200
# Epoch 60/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.5699 - accuracy: 0.8215 - val_loss: 0.6499 - val_accuracy: 0.7000
# Epoch 61/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.5650 - accuracy: 0.8096 - val_loss: 0.5601 - val_accuracy: 0.8600
# Epoch 62/100
# 2/2 [==============================] - 15s 5s/step - loss: 0.5295 - accuracy: 0.8454 - val_loss: 0.5530 - val_accuracy: 0.7600
# Epoch 63/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.5053 - accuracy: 0.8487 - val_loss: 0.5835 - val_accuracy: 0.8200
# Epoch 64/100
# 2/2 [==============================] - 17s 5s/step - loss: 0.4836 - accuracy: 0.8547 - val_loss: 0.5426 - val_accuracy: 0.8200
# Epoch 65/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.4683 - accuracy: 0.8540 - val_loss: 0.5674 - val_accuracy: 0.8000
# Epoch 66/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.4473 - accuracy: 0.8560 - val_loss: 0.5885 - val_accuracy: 0.8200
# Epoch 67/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.4444 - accuracy: 0.8673 - val_loss: 0.5392 - val_accuracy: 0.8400
# Epoch 68/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.4108 - accuracy: 0.8839 - val_loss: 0.5688 - val_accuracy: 0.8600
# Epoch 69/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.4054 - accuracy: 0.8872 - val_loss: 0.5542 - val_accuracy: 0.8400
# Epoch 70/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.3962 - accuracy: 0.8799 - val_loss: 0.5773 - val_accuracy: 0.8400
# Epoch 71/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.3717 - accuracy: 0.8925 - val_loss: 0.5721 - val_accuracy: 0.8200
# Epoch 72/100
# 2/2 [==============================] - 16s 5s/step - loss: 0.3554 - accuracy: 0.9031 - val_loss: 0.5751 - val_accuracy: 0.8400

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.legend(["loss", "val_loss"])
plt.show()

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["accuracy", "val_accuracy"])
plt.show()

# %%
our_cnn.save_weights("weights/model_for_fun2")
our_cnn.save("model/simple.h5")

# %% [markdown]
# Loading of the model weights directly into the model

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
model_loaded = create_cnn_model(
    inShape=(224, 224, 3),
    convNum=[8,16,24,32,40],
    hNum=[50],
    hAct='relu',
    outNum=10,
    loss=tf.keras.losses.SparseCategoricalCrossentropy()
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 224, 224, 8)       224
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 8)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 16)      1168
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 24)        3480
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 24)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        6944
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 40)        11560
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 40)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1960)              0
#
#  dense_2 (Dense)             (None, 50)                98050
#
#  dense_3 (Dense)             (None, 10)                510
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 121,936
# Trainable params: 121,936
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# wczytuje parametry do zainicjalizowanego modelu
model_loaded.load_weights("weights/model_for_fun2")

# %%
# tu wrzucasz dane do predict które chcesz sprawdzić
y_pred = model_loaded.predict(x_test)
print(classification_report(y_test, y_pred.argmax(axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.75      0.60      0.67         5
#            2       0.60      0.60      0.60         5
#            3       0.83      1.00      0.91         5
#            4       0.80      0.80      0.80         5
#            5       1.00      1.00      1.00         5
#            6       0.83      1.00      0.91         5
#            7       0.67      0.80      0.73         5
#            8       1.00      1.00      1.00         5
#            9       1.00      0.80      0.89         5
#
#     accuracy                           0.84        50
#    macro avg       0.85      0.84      0.84        50
# weighted avg       0.85      0.84      0.84        50

# %% [markdown]
# Loading whole model (model with the weights)

# %%
def read_images_from_directory(directory):
    test_imgs = glob2.glob(os.path.join(directory)+"/*")
    zero_img = cv2.cvtColor(cv2.imread(test_imgs[0]),cv2.COLOR_BGR2RGB).reshape(1,224,224,3)
    filenames = [test_imgs[0]]
    dataset = zero_img
    
    for img in test_imgs[1:]:
            tmp_img = cv2.cvtColor(cv2.imread(img),cv2.COLOR_BGR2RGB).reshape(1,224,224,3)
            dataset = np.concatenate((dataset, tmp_img), axis=0)
            filenames.append(img)

    return dataset, filenames

# %%
model_loaded_h5 = tf.keras.models.load_model("model/simple.h5")

# %%
images_to_predict, filenames = read_images_from_directory('images_to_test')
y_pred = model_loaded_h5.predict(images_to_predict)
for index, pred in enumerate(y_pred):
    print(f'Picture {filenames[index]} is {species[pred.argmax()]} with {pred.max():.2f}% confidence')
# Out:
# Picture images_to_test\1.jpg is ABBOTTS BABBLER with 0.99% confidence
# Picture images_to_test\11.jpg is ABYSSINIAN GROUND HORNBILL with 0.80% confidence
# Picture images_to_test\14.jpg is AFRICAN CROWNED CRANE with 0.87% confidence
# Picture images_to_test\2.jpg is ALEXANDRINE PARAKEET with 1.00% confidence
# Picture images_to_test\3.jpg is ABBOTTS BABBLER with 0.99% confidence
# Picture images_to_test\31.jpg is ALBATROSS with 0.87% confidence
# Picture images_to_test\4.jpg is AFRICAN FIREFINCH with 1.00% confidence
